# %%
import pickle
import numpy as np

# %%
pipe = pickle.load(open("pipe.pkl", "rb"))
test_input = np.array([4, 'male', 31.0, 0, 0, 10.5, 'S'], dtype = "object").reshape(1, 7)

# %%
pipe.predict(test_input)
# Out:
# c:\Users\Lenovo\Desktop\Access\ML\ds_env\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# c:\Users\Lenovo\Desktop\Access\ML\ds_env\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# array([0], dtype=int64)
