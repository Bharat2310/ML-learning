# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import numpy as np
import cv2 as cv

# %%
image = cv.imread("test.jpg")
image1 = cv.cvtColor(image, cv.COLOR_BGR2RGB) 
# print("image1", image1)
print("image", image)
# Out:
# image [[[85 76 33]
#   [79 70 27]
#   [82 72 32]
#   ...
#   [18 25  0]
#   [27 35  5]
#   [32 37  8]]
#
#  [[78 69 26]
#   [73 64 21]
#   [81 71 31]
#   ...
#   [46 53 26]
#   [53 60 33]
#   [72 77 48]]
#
#  [[82 73 30]
#   [84 75 32]
#   [91 81 41]
#   ...
#   [59 64 37]
#   [52 59 32]
#   [50 55 26]]
#
#  ...
#
#  [[27 24 10]
#   [22 19  5]
#   [18 15  1]
#   ...
#   [18 24 13]
#   [18 25 12]
#   [17 24 11]]
#
#  [[32 26 13]
#   [27 21  8]
#   [19 16  2]
#   ...
#   [30 36 25]
#   [22 29 16]
#   [20 27 14]]
#
#  [[36 30 17]
#   [31 25 12]
#   [23 20  6]
#   ...
#   [43 49 38]
#   [28 35 22]
#   [21 30 17]]]

# %%
pixel = image1.reshape((-1, 3))

# %%
image1.shape, pixel
# Out:
# ((350, 625, 3),
#  array([[33, 76, 85],
#         [27, 70, 79],
#         [32, 72, 82],
#         ...,
#         [38, 49, 43],
#         [22, 35, 28],
#         [17, 30, 21]], shape=(218750, 3), dtype=uint8))

# %%
kmeans = KMeans(n_clusters=8, n_init="auto", random_state=12)
kmeans.fit(pixel)
# Out:
# KMeans(random_state=12)

# %%
dominant_colors = kmeans.cluster_centers_.astype(int)
dominant_colors
# Out:
# array([[ 82,  77,  49],
#        [179, 140,  78],
#        [ 19,  34,  29],
#        [244, 213, 141],
#        [ 90, 108,  96],
#        [134, 105,  57],
#        [ 44,  65,  60],
#        [223, 176, 102]])

# %%
quantized_pixels = dominant_colors[kmeans.labels_]
quantized_image = quantized_pixels.reshape(image.shape)

# %%
fig, ax = plt.subplots(1,2, figsize=(12, 12))
ax[0].imshow(image1)
ax[0].set_title('Original Image')
ax[0].axis('off')

ax[1].imshow(quantized_image)
ax[1].set_title('Quantized Image')
ax[1].axis('off')
plt.tight_layout()
plt.show()

# %%
def rgb_to_hex(rgb):
    return '#%02x%02x%02x' % tuple(rgb)

plt.figure(figsize=(12, 2))
plt.title("Dominant Color Palette")1
for i, color in enumerate(dominant_colors):
    plt.subplot(1, 16, i + 1)
    palette_square = np.zeros((10, 10, 3), dtype=int) + color
    plt.imshow(palette_square)
    plt.axis('off')
    
    hex_code = rgb_to_hex(color)
    plt.text(5, 12, hex_code, fontsize=8, ha='center', rotation=45)

plt.show()
